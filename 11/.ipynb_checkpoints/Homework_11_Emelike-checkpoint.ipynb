# %%
import numpy as np 
import pandas as pd
import datetime
import matplotlib as plt
import re
# %matplotlib inline

# %%
df = pd.read_csv('violations.csv', nrows=1000, parse_dates=['Issue Date'])

# %%
df.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect    ',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Summons Number                                int64
# Plate ID                                     object
# Registration State                           object
# Plate Type                                   object
# Issue Date                           datetime64[ns]
# Violation Code                                int64
# Vehicle Body Type                            object
# Vehicle Make                                 object
# Issuing Agency                               object
# Street Code1                                  int64
# Street Code2                                  int64
# Street Code3                                  int64
# Vehicle Expiration Date                       int64
# Violation Location                          float64
# Violation Precinct                            int64
# Issuer Precinct                               int64
# Issuer Code                                   int64
# Issuer Command                               object
# Issuer Squad                                  int64
# Violation Time                               object
# Time First Observed                          object
# Violation County                             object
# Violation In Front Of Or Opposite            object
# House Number                                 object
# Street Name                                  object
# Intersecting Street                          object
# Date First Observed                           int64
# Law Section                                   int64
# Sub Division                                 object
# Violation Legal Code                        float64
# Days Parking In Effect                       object
# From Hours In Effect                         object
# To Hours In Effect                           object
# Vehicle Color                                object
# Unregistered Vehicle?                         int64
# Vehicle Year                                  int64
# Meter Number                                 object
# Feet From Curb                                int64
# Violation Post Code                         float64
# Violation Description                       float64
# No Standing or Stopping Violation           float64
# Hydrant Violation                           float64
# Double Parking Violation                    float64
# dtype: object

# %% [markdown]
# ### 1. I want to make sure my Plate ID is a string. Can't lose the leading zeroes!

# %%
# checks data type of each value in series Plate ID by printing if type does not equal string
# all values are strings
for x in df['Plate ID']: 
    if type(x) != str:
        print(type(x))

# %% [markdown]
# ### 2. I don't think anyone's car was built in 0AD. Discard the '0's as NaN.

# %%
df['Vehicle Year'] = df['Vehicle Year'].replace(0, np.nan)
df['Vehicle Year'] = pd.to_datetime(df['Vehicle Year'], format='%Y', errors = 'coerce')

# %% [markdown]
# ### 3. I want the dates to be dates! Read the read_csv documentation to find out how to make pandas automatically parse dates.

# %%
# see where I read in csv for inclusion of parse_date arg

# %% [markdown]
# ### 4. "Date first observed" is a pretty weird column, but it seems like it has a date hiding inside. Using a function with .apply, transform the string (e.g. "20140324") into a Python date. Make the 0's show up as NaN.

# %%
df['Date First Observed'] = df['Date First Observed'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d', errors='coerce'))

# %% [markdown]
# ### 5. "Violation time" is... not a time. Make it a time.

# %%
def remove_char(x):
    x = x[:-1]
    return x
def insert_char(x):
    x = x[:2] + ':' + x[2:]
    return x

# %%
# removes 'A' and 'P' from original values in Violation Time
df['Violation Time2'] = df['Violation Time'].apply(lambda x: remove_char(str(x)))
# inserts colon in to string 
df['Violation Time3'] = df['Violation Time2'].apply(lambda x: insert_char(str(x)))

# %%
#makes values datetime format, allowing .to_datetime to infer format from string
df['Violation Time4'] = df['Violation Time3'].apply(lambda x: pd.to_datetime(str(x), infer_datetime_format=True, errors='coerce'))
#selects only time from timestamp 
df['Violation Time'] = df['Violation Time4'].dt.time

# %%
# deletes temporary variables used to make violation time a time 
df=df.drop(df.columns[[43, 44, 45]], axis=1)
df.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect    ',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation'],
#       dtype='object')

# %% [markdown]
# ### 6.  There sure are a lot of colors of cars, too bad so many of them are the same. Make "BLK" and "BLACK", "WT" and "WHITE", and any other combinations that you notice.

# %%
def clean_color(x): 
    if x == 'BLK': 
        print(x)
        x = x.replace('BLK','BLACK')
        print('Now', x)
    elif x == 'BK': 
        print(x)
        x = x.replace('BK','BLACK')
        print('Now', x)
    elif x == 'W': 
        print(x)
        x = x.replace('W','WHITE')
        print('Now', x)
    elif x == 'WH': 
        print(x)
        x = x.replace('WH','WHITE')
        print('Now', x)
    elif x == 'WHT': 
        print(x)
        x = x.replace('WHT','WHITE')
        print('Now', x)
    elif x == 'WT': 
        print(x)
        x = x.replace('WT','WHITE')
        print('Now', x)
    elif x == 'GY': 
        print(x)
        x = x.replace('GY','GREY')
        print('Now', x)
    elif x == 'GRAY': 
        print(x)
        x = x.replace('GRAY','GREY')
        print('Now', x)
    elif x == 'GRY': 
        print(x)
        x = x.replace('GRY','GREY')
        print('Now', x)
    elif x == 'G/Y': 
        print(x)
        x = x.replace('G/Y','GREY')
        print('Now', x)
    elif x == 'BR': 
        print(x)
        x = x.replace('BR','BROWN')
        print('Now', x)
    elif x == 'BRW': 
        print(x)
        x = x.replace('BRW','BROWN')
        print('Now', x)
    elif x == 'TN': 
        print(x)
        x = x.replace('GY','TAN')
        print('Now', x)
    elif x == 'RD': 
        print(x)
        x = x.replace('RD','RED')
        print('Now', x)
    elif x == 'BL': 
        print(x)
        x = x.replace('BL','BLUE')
        print('Now', x)
    elif x == 'BLU': 
        print(x)
        x = x.replace('BLU','BLUE')
        print('Now', x)
    elif x == 'SIL':
        print(x)
        x = x.replace('SIL','SILVER')
        print('Now', x)  
    elif x == 'SILVE':
        print(x)
        x = x.replace('SILVE','SILVER')
        print('Now', x) 
    elif x == 'BURGA':
        print(x)
        x = x.replace('BURGA','BURGANDY')
        print('Now', x) 
    elif x == 'PURPL':
        print(x)
        x = x.replace('PURPL','PURPLE')
        print('Now', x) 
    elif x == 'PUR':
        print(x)
        x = x.replace('PUR','PURPLE')
        print('Now', x) 
    elif x == 'YELLO':
        print(x)
        x = x.replace('YELLO','YELLOW')
        print('Now', x) 
    elif x == 'YW':
        print(x)
        x = x.replace('YW','YELLOW')
        print('Now', x)
    elif x == 'OR':
        print(x)
        x = x.replace('OR','ORANGE')
        print('Now', x)
    elif x == 'GL':
        print(x)
        x = x.replace('GL','GOLD')
        print('Now', x)
    elif x == 'GR':
        print(x)
        x = x.replace('GR','GREEN')
        print('Now', x)
    elif x == 'GRN':
        print(x)
        x = x.replace('GRN','GREEN')
        print('Now', x)
    elif x == 'G':
        print(x)
        x = x.replace('G','GREEN')
        print('Now', x)
    return x

# %%
df['Vehicle Color'] = df['Vehicle Color'].apply(lambda x: clean_color(x))
df['Vehicle Color']
# Out:
# GY
# Now GREY
# WH
# Now WHITE
# WH
# Now WHITE
# BR
# Now BROWN
# RD
# Now RED
# GRAY
# Now GREY
# WH
# Now WHITE
# GY
# Now GREY
# GRAY
# Now GREY
# TN
# Now TN
# BK
# Now BLACK
# WHT
# Now WHITE
# WH
# Now WHITE
# GR
# Now GREEN
# RD
# Now RED
# GY
# Now GREY
# GY
# Now GREY
# BL
# Now BLUE
# BK
# Now BLACK
# BLU
# Now BLUE
# WHT
# Now WHITE
# GRAY
# Now GREY
# BR
# Now BROWN
# GY
# Now GREY
# BK
# Now BLACK
# BLK
# Now BLACK
# SILVE
# Now SILVER
# BK
# Now BLACK
# GRAY
# Now GREY
# WH
# Now WHITE
# GY
# Now GREY
# SILVE
# Now SILVER
# BK
# Now BLACK
# SILVE
# Now SILVER
# YELLO
# Now YELLOW
# GRY
# Now GREY
# WHT
# Now WHITE
# WHT
# Now WHITE
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# GRAY
# Now GREY
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# GRAY
# Now GREY
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# GRAY
# Now GREY
# GRY
# Now GREY
# SILVE
# Now SILVER
# YELLO
# Now YELLOW
# BLK
# Now BLACK
# BL
# Now BLUE
# BLK
# Now BLACK
# BL
# Now BLUE
# GRAY
# Now GREY
# GRAY
# Now GREY
# GY
# Now GREY
# BK
# Now BLACK
# BK
# Now BLACK
# GY
# Now GREY
# GY
# Now GREY
# GRAY
# Now GREY
# WH
# Now WHITE
# GRAY
# Now GREY
# WH
# Now WHITE
# WH
# Now WHITE
# OR
# Now ORANGE
# BL
# Now BLUE
# W
# Now WHITE
# WHT
# Now WHITE
# GRAY
# Now GREY
# BK
# Now BLACK
# SIL
# Now SILVER
# WHT
# Now WHITE
# WHT
# Now WHITE
# WHT
# Now WHITE
# GRAY
# Now GREY
# BLK
# Now BLACK
# BLK
# Now BLACK
# BLK
# Now BLACK
# GR
# Now GREEN
# BK
# Now BLACK
# WH
# Now WHITE
# BLK
# Now BLACK
# YELLO
# Now YELLOW
# YELLO
# Now YELLOW
# WHT
# Now WHITE
# BL
# Now BLUE
# PURPL
# Now PURPLE
# G/Y
# Now GREY
# GY
# Now GREY
# BK
# Now BLACK
# WHT
# Now WHITE
# BRW
# Now BROWN
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# WHT
# Now WHITE
# GRY
# Now GREY
# BLK
# Now BLACK
# GRY
# Now GREY
# GRY
# Now GREY
# GRY
# Now GREY
# BLK
# Now BLACK
# GRAY
# Now GREY
# GRAY
# Now GREY
# SILVE
# Now SILVER
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# SILVE
# Now SILVER
# YELLO
# Now YELLOW
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# SILVE
# Now SILVER
# PURPL
# Now PURPLE
# SILVE
# Now SILVER
# GRAY
# Now GREY
# SILVE
# Now SILVER
# BLK
# Now BLACK
# SILVE
# Now SILVER
# BLK
# Now BLACK
# SILVE
# Now SILVER
# BLK
# Now BLACK
# BLK
# Now BLACK
# BLK
# Now BLACK
# GRAY
# Now GREY
# YELLO
# Now YELLOW
# WH
# Now WHITE
# GY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# BLK
# Now BLACK
# SILVE
# Now SILVER
# BK
# Now BLACK
# BLK
# Now BLACK
# GY
# Now GREY
# GRAY
# Now GREY
# BL
# Now BLUE
# BLK
# Now BLACK
# SILVE
# Now SILVER
# BL
# Now BLUE
# GRY
# Now GREY
# WH
# Now WHITE
# RD
# Now RED
# WH
# Now WHITE
# BK
# Now BLACK
# GY
# Now GREY
# BLK
# Now BLACK
# WHT
# Now WHITE
# BL
# Now BLUE
# WH
# Now WHITE
# BK
# Now BLACK
# WHT
# Now WHITE
# BR
# Now BROWN
# WHT
# Now WHITE
# BLK
# Now BLACK
# GRY
# Now GREY
# BL
# Now BLUE
# BK
# Now BLACK
# GY
# Now GREY
# WH
# Now WHITE
# WHT
# Now WHITE
# WHT
# Now WHITE
# TN
# Now TN
# WHT
# Now WHITE
# WHT
# Now WHITE
# BLK
# Now BLACK
# GRY
# Now GREY
# WHT
# Now WHITE
# GRY
# Now GREY
# BK
# Now BLACK
# WH
# Now WHITE
# BK
# Now BLACK
# WH
# Now WHITE
# GY
# Now GREY
# G
# Now GREEN
# BK
# Now BLACK
# WH
# Now WHITE
# W
# Now WHITE
# GY
# Now GREY
# BK
# Now BLACK
# YELLO
# Now YELLOW
# G
# Now GREEN
# GY
# Now GREY
# BL
# Now BLUE
# GY
# Now GREY
# BLK
# Now BLACK
# BK
# Now BLACK
# BK
# Now BLACK
# GY
# Now GREY
# GY
# Now GREY
# WH
# Now WHITE
# BK
# Now BLACK
# BR
# Now BROWN
# WH
# Now WHITE
# BR
# Now BROWN
# BL
# Now BLUE
# GR
# Now GREEN
# BK
# Now BLACK
# GL
# Now GOLD
# GY
# Now GREY
# SILVE
# Now SILVER
# GY
# Now GREY
# BLK
# Now BLACK
# WHT
# Now WHITE
# BR
# Now BROWN
# RD
# Now RED
# BK
# Now BLACK
# BK
# Now BLACK
# GY
# Now GREY
# BLK
# Now BLACK
# BR
# Now BROWN
# BR
# Now BROWN
# BL
# Now BLUE
# BLK
# Now BLACK
# GY
# Now GREY
# BL
# Now BLUE
# GY
# Now GREY
# GY
# Now GREY
# BK
# Now BLACK
# BL
# Now BLUE
# BR
# Now BROWN
# WHT
# Now WHITE
# BK
# Now BLACK
# BLK
# Now BLACK
# GY
# Now GREY
# GY
# Now GREY
# BR
# Now BROWN
# GL
# Now GOLD
# BK
# Now BLACK
# BK
# Now BLACK
# GY
# Now GREY
# GY
# Now GREY
# GRAY
# Now GREY
# SILVE
# Now SILVER
# YELLO
# Now YELLOW
# BK
# Now BLACK
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# BK
# Now BLACK
# WH
# Now WHITE
# GRAY
# Now GREY
# GRAY
# Now GREY
# BK
# Now BLACK
# BK
# Now BLACK
# GY
# Now GREY
# WH
# Now WHITE
# GY
# Now GREY
# YW
# Now YELLOW
# YELLO
# Now YELLOW
# WH
# Now WHITE
# BLK
# Now BLACK
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# BLK
# Now BLACK
# BLK
# Now BLACK
# BK
# Now BLACK
# SILVE
# Now SILVER
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# BLK
# Now BLACK
# BLK
# Now BLACK
# GRAY
# Now GREY
# BLK
# Now BLACK
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# BK
# Now BLACK
# GY
# Now GREY
# BK
# Now BLACK
# BLK
# Now BLACK
# GY
# Now GREY
# RD
# Now RED
# GY
# Now GREY
# GRY
# Now GREY
# WHT
# Now WHITE
# RD
# Now RED
# TN
# Now TN
# GRN
# Now GREEN
# BK
# Now BLACK
# GY
# Now GREY
# GRN
# Now GREEN
# GRAY
# Now GREY
# WHT
# Now WHITE
# BK
# Now BLACK
# GY
# Now GREY
# RD
# Now RED
# WH
# Now WHITE
# RD
# Now RED
# BK
# Now BLACK
# RD
# Now RED
# GR
# Now GREEN
# BK
# Now BLACK
# GR
# Now GREEN
# GRY
# Now GREY
# BLK
# Now BLACK
# WHT
# Now WHITE
# PUR
# Now PURPLE
# BLK
# Now BLACK
# WHT
# Now WHITE
# BLK
# Now BLACK
# WHT
# Now WHITE
# WHT
# Now WHITE
# GRY
# Now GREY
# BLK
# Now BLACK
# GRY
# Now GREY
# BLK
# Now BLACK
# GRY
# Now GREY
# WHT
# Now WHITE
# WHT
# Now WHITE
# WH
# Now WHITE
# BK
# Now BLACK
# GY
# Now GREY
# WHT
# Now WHITE
# GY
# Now GREY
# BL
# Now BLUE
# BLK
# Now BLACK
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# SILVE
# Now SILVER
# GRAY
# Now GREY
# BLK
# Now BLACK
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# SILVE
# Now SILVER
# GRAY
# Now GREY
# GRAY
# Now GREY
# SILVE
# Now SILVER
# BLK
# Now BLACK
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# GRAY
# Now GREY
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# YELLO
# Now YELLOW
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# GRAY
# Now GREY
# YELLO
# Now YELLOW
# G
# Now GREEN
# GRAY
# Now GREY
# GRAY
# Now GREY
# SILVE
# Now SILVER
# GRAY
# Now GREY
# GRAY
# Now GREY
# WH
# Now WHITE
# GRAY
# Now GREY
# WH
# Now WHITE
# WH
# Now WHITE
# GY
# Now GREY
# GY
# Now GREY
# GY
# Now GREY
# BL
# Now BLUE
# WH
# Now WHITE
# GY
# Now GREY
# WH
# Now WHITE
# GY
# Now GREY
# BK
# Now BLACK
# YELLO
# Now YELLOW
# GRAY
# Now GREY
# SILVE
# Now SILVER
# SILVE
# Now SILVER
# PURPL
# Now PURPLE
# BLK
# Now BLACK
# BL
# Now BLUE
# BLK
# Now BLACK
# SILVE
# Now SILVER
# BLK
# Now BLACK
# GRAY
# Now GREY
# BL
# Now BLUE
# BURGA
# Now BURGANDY
# YELLO
# Now YELLOW
# GRY
# Now GREY
# GRAY
# Now GREY
# SILVE
# Now SILVER
# 0          GREY
# 1         WHITE
# 2           NaN
# 3         WHITE
# 4         BROWN
# 5           RED
# 6            GN
# 7         WHITE
# 8         WHITE
# 9         BLACK
# 10         BLUE
# 11          TAN
# 12         GOLD
# 13        WHITE
# 14        GREEN
# 15        WHITE
# 16         GREY
# 17        GREEN
# 18        WHITE
# 19        WHITE
# 20          TAN
# 21         GREY
# 22         GREY
# 23           TN
# 24        BLACK
# 25        WHITE
# 26        WHITE
# 27        GREEN
# 28          RED
# 29         GREY
#          ...
# 970       BLACK
# 971      SILVER
# 972       BLACK
# 973        GREY
# 974        GREY
# 975        BLUE
# 976        GOLD
# 977         RED
# 978    BURGANDY
# 979       BLACK
# 980       WHITE
# 981       BLACK
# 982        BLUE
# 983        GOLD
# 984      YELLOW
# 985        BLUE
# 986        GREY
# 987        BLUE
# 988         RED
# 989       GREEN
# 990       GREEN
# 991       BLACK
# 992        GREY
# 993        GREY
# 994        GREY
# 995       WHITE
# 996        BLUE
# 997      SILVER
# 998       BLACK
# 999        GREY
# Name: Vehicle Color, dtype: object

# %%
#check for remaining color abbreviations
for x in df['Vehicle Color']:
    if len(str(x)) <= 2: 
        print(x)
# Out:
# GN
# TN
# GN
# TN
# IL
# TN

# %% [markdown]
# ### 7. Join the data with the Parking Violations Code dataset from the NYC Open Data site.

# %%
df2 = pd.read_csv('DOF_Parking_Violation_Codes.csv')

# %%
df2
# Out:
#      CODE                                         DEFINITION  \
# 0      10  Stopping, standing or parking where a sign, st...
# 1      11  Hotel Loading/Unloading: Standing or parking w...
# 2      12  Snow Emergency: Standing or parking where stan...
# 3      13  Taxi Stand: Standing or parking where standing...
# 4      14  General No Standing: Standing or parking where...
# 5      16  Truck Loading/Unloading: Standing or parking w...
# 6      17  Authorized Vehicles Only: Standing or parking ...
# 7      18  Bus Lane: Standing or parking where standing i...
# 8      19  Bus Stop: Standing or parking where standing i...
# 9      20  General No Parking: No parking where parking i...
# 10     21  Street Cleaning: No parking where parking is n...
# 11     22  Hotel Loading/Unloading: No parking where park...
# 12     23  Taxi Stand: No parking where parking is not al...
# 13     24  Authorized Vehicles Only: No parking where par...
# 14     25  Standing at a commuter van stop, other than te...
# 15     26  Standing at a for-hire vehicle stop, other tha...
# 16     27  No parking in a handicapped zone (off-street o...
# 17     28                       Overtime standing (diplomat)
# 18     31  Standing of a non-commercial vehicle in a comm...
# 19     32  Parking at a broken or missing meter for longe...
# 20     33  "Feeding Meter" -- parking in a metered space ...
# 21     34  Expired Meter -- parking in a metered space wh...
# 22     35  Parking in a meter space for the purpose of di...
# 23  37-38  Muni Meter --\n(37) Parking in excess of the a...
# 24     39  Parking for longer than the maximum time permi...
# 25     69  Failing to show a muni-meter receipt, commerci...
# 26     40  Stopping, standing or parking closer than 15 f...
# 27     42  Parking in a Muni Metered space in a commercia...
# 28     43  Parking in a commercial metered zone in which ...
# 29     44  Parking in a commercial metered zone for longe...
# ..    ...                                                ...
# 54     71  Standing or parking a vehicle without showing ...
# 55     72  Standing or parking a vehicle with NY Plates a...
# 56     73  Standing or parking a vehicle showing an expir...
# 57     74  Standing or parking a vehicle without properly...
# 58     75  Standing or parking a vehicle in which the Lic...
# 59     77  Parking a bus, unless allowed by signs. A char...
# 60     78  Parking a Commercial Vehicle on a residential ...
# 61     79  For a bus without passengers, waiting at a cur...
# 62     80  Standing or parking a vehicle without head lam...
# 63     81                        No standing except diplomat
# 64     82  Standing or parking a Commercial Vehicle unles...
# 65     83  Standing or parking a vehicle which is not pro...
# 66     84  Parking a Commercial Vehicle on any city stree...
# 67     85  Parking a Commercial Vehicle more than 3 hours...
# 68     86  Standing or parking a vehicle to make pickups,...
# 69     89  Standing or parking a vehicle in the Garment D...
# 70     91  Parking in order to sell a vehicle by a person...
# 71     92  Parking in order to wash, grease, or repair a ...
# 72     93  Stopping, standing or parking on paved roadway...
# 73     94  Vehicle Release Agreement code associated with...
# 74     96  Standing or parking within 50 feet of the near...
# 75     97  Parking in a vacant lot. A vehicle may be park...
# 76     98  Standing or parking in front of a public or pr...
# 77     99  All other parking, standing or stopping violat...
# 78     04  Vehicles parked illegally south of Houston Str...
# 79     05      Failure to make a right turn from a bus lane.
# 80     06  Parking a tractor-trailer on a residential str...
# 81     07  Vehicles photographed going through a red ligh...
# 82     08               Vehicle idling in a restricted area.
# 83     09  Blocking an Intersection: Obstructing traffic ...
#
#                 Manhattan  96th St. & below  \
# 0                                     $115
# 1                                     $115
# 2                                      $95
# 3                                     $115
# 4                                     $115
# 5                                      $95
# 6                                      $95
# 7                                     $115
# 8                                     $115
# 9                                      $65
# 10                                     $65
# 11                                     $60
# 12                                     $65
# 13                                     $65
# 14                                    $115
# 15                                    $115
# 16                                    $180
# 17                                     $95
# 18                                    $115
# 19                                     $65
# 20                                     $65
# 21                                     $65
# 22                                     $65
# 23                                     $65
# 24                                     $65
# 25                                     $65
# 26                                    $115
# 27                                     $65
# 28                                     $65
# 29                                     $65
# ..                                      ...
# 54                                     $65
# 55                                     $65
# 56                                     $65
# 57                                     $65
# 58                                     $65
# 59                                     $65
# 60                                     $65
# 61                                    $115
# 62                                     $60
# 63                                     $95
# 64                                    $115
# 65                                     $65
# 66                                     $65
# 67                                     $65
# 68                                    $115
# 69                                    $115
# 70                                     $65
# 71                                     $65
# 72                                     $65
# 73  100\n(Regular Tow, plus violation fine)
# 74                                     $95
# 75                                     $65
# 76                                     $95
# 77                                     vary
# 78                                    $115
# 79                                    $115
# 80   1st Offense - $265\n2nd Offense - $515
# 81                                    $50
# 82                                    $115
# 83                                    $115
#
#                            All Other Areas
# 0                                    $115
# 1                                    $115
# 2                                     $95
# 3                                    $115
# 4                                    $115
# 5                                     $95
# 6                                     $95
# 7                                    $115
# 8                                    $115
# 9                                     $60
# 10                                    $45
# 11                                    $60
# 12                                    $60
# 13                                    $60
# 14                                   $115
# 15                                   $115
# 16                                   $180
# 17                                    $95
# 18                                   $115
# 19                                    $35
# 20                                    $35
# 21                                    $35
# 22                                    $35
# 23                                    $35
# 24                                    $60
# 25                                    $65
# 26                                   $115
# 27                                    $35
# 28                                    $35
# 29                                    $35
# ..                                     ...
# 54                                    $65
# 55                                    $65
# 56                                    $65
# 57                                    $65
# 58                                    $65
# 59                                    $45
# 60                                    $65
# 61                                   $115
# 62                                    $45
# 63                                    $95
# 64                                   $115
# 65                                    $65
# 66                                    $45
# 67                                    $65
# 68                                   $115
# 69                                   $115
# 70                                    $45
# 71                                    $45
# 72                                    $65
# 73   $200 (Heavy Tow, plus violation fine)
# 74                                    $95
# 75                                    $45
# 76                                    $95
# 77                                    vary
# 78                                     NaN
# 79                                   $115
# 80  2nd Offense - $265\n2nd Offense - $515
# 81                                   $50
# 82                                   $115
# 83                                   $115
#
# [84 rows x 4 columns]

# %%
# change format to string to match violation codes data set format 
df['Violation Code'] = df['Violation Code'].apply(lambda x: str(x).strip())

# %%
# check formatting and string length
for x in df['Violation Code']:
    if type(x) != str: 
        print(type(x))
    if len(x) > 2: 
        print(x)

# %%
df3 = pd.merge(df, df2, left_on='Violation Code', right_on='CODE', how='left', indicator=True)

# %%
# unsuccessful merges bc Violation Code 41 does not exist in Violation codes data.
# and bc 38 in documented at 37-38 in Violation codes data 
df3[df3['_merge']=='left_only']
# Out:
#      Summons Number Plate ID Registration State Plate Type Issue Date  \
# 4        1283294187  91648MC                 NY        COM 2013-08-08
# 37       1288360800  HYM4303                 PA        PAS 2013-08-06
# 87       1294713218  GFC8215                 NY        PAS 2013-08-13
# 88       1294713220   6417CO                 CT        COM 2013-08-13
# 217      1321932730   900ZIH                 CA        PAS 2013-08-12
# 501      1295572450  GBJ3633                 NY        PAS 2013-07-20
# 581      1309169688    98981                 NY        COM 2013-08-01
# 885      1334596554  JFE4755                 PA        PAS 2013-08-03
# 930      1334738531    U3261                 99        COM 2013-08-22
# 981      1335087930  GGB3579                 NY        PAS 2013-07-27
#
#     Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 4               41              TRLR          GMC              P
# 37              41               SDN        MITSU              P
# 87              38              SUBN        CHEVR              P
# 88              38               VAN        CHEVR              P
# 217             41              SUBN         AUDI              S
# 501             37               SDN        NISSA              P
# 581             38               VAN        DODGE              P
# 885             41              SUBN        CHEVR              X
# 930              6              TRLR        STRIC              S
# 981             41               SDN        HYUND              P
#
#      Street Code1    ...      Violation Post Code  Violation Description  \
# 4           37240    ...                      NaN                    NaN
# 37          29090    ...                      NaN                    NaN
# 87              0    ...                      NaN                    NaN
# 88              0    ...                      NaN                    NaN
# 217             0    ...                      NaN                    NaN
# 501             0    ...                      NaN                    NaN
# 581         34770    ...                      NaN                    NaN
# 885         11710    ...                      NaN                    NaN
# 930         73570    ...                      NaN                    NaN
# 981         73110    ...                      NaN                    NaN
#
#      No Standing or Stopping Violation  Hydrant Violation  \
# 4                                  NaN                NaN
# 37                                 NaN                NaN
# 87                                 NaN                NaN
# 88                                 NaN                NaN
# 217                                NaN                NaN
# 501                                NaN                NaN
# 581                                NaN                NaN
# 885                                NaN                NaN
# 930                                NaN                NaN
# 981                                NaN                NaN
#
#      Double Parking Violation  CODE  DEFINITION Manhattan  96th St. & below  \
# 4                         NaN   NaN         NaN                         NaN
# 37                        NaN   NaN         NaN                         NaN
# 87                        NaN   NaN         NaN                         NaN
# 88                        NaN   NaN         NaN                         NaN
# 217                       NaN   NaN         NaN                         NaN
# 501                       NaN   NaN         NaN                         NaN
# 581                       NaN   NaN         NaN                         NaN
# 885                       NaN   NaN         NaN                         NaN
# 930                       NaN   NaN         NaN                         NaN
# 981                       NaN   NaN         NaN                         NaN
#
#      All Other Areas     _merge
# 4                NaN  left_only
# 37               NaN  left_only
# 87               NaN  left_only
# 88               NaN  left_only
# 217              NaN  left_only
# 501              NaN  left_only
# 581              NaN  left_only
# 885              NaN  left_only
# 930              NaN  left_only
# 981              NaN  left_only
#
# [10 rows x 48 columns]

# %% [markdown]
# ### 8. How much money did NYC make off of parking violations?

# %%
# removes unsuccessful merges
df4 = df3[df3['_merge'] !='left_only']

# %%
# Create boolean variable to indicate 0/1: Parking violation 
df4['Parking Violation'] = df4['DEFINITION'].str.contains('[Pp]arking') | df4['DEFINITION'].str.contains('[Pp]arked')
df4['Parking Violation'].value_counts()
df4[df4['Parking Violation'] == False]
# Out:
# /Users/mercyemelike/.virtualenvs/data_analysis/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#      Summons Number Plate ID Registration State Plate Type Issue Date  \
# 32       1287518126      WMI                 CT        PAS 2013-07-24
# 51       6020309034  GEW4836                 99        PAS 2013-07-18
# 57       1293094389  GDS9810                 NJ        PAS 2013-06-20
# 378      1333131951   947WT5                 MA        PAS 2013-07-22
# 384      1333509005   447ZRW                 CT        PAS 2013-07-20
# 390      6020310784   447ZRW                 CT        PAS 2013-07-20
# 402      1333711438   ZTD55E                 NJ        PAS 2013-07-06
# 520      6020314583  87336JV                 PA        PAS 2013-07-26
# 625      6020342748   HWD923                 SC        PAS 2013-07-22
# 746      1333717192   402YBY                 CT        PAS 2013-07-13
# 747      1333717209   H77CXW                 NJ        PAS 2013-07-13
#
#     Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 32              31              SUBN        ME/BE              T
# 51              94               SDN        ACURA              X
# 57              31               SDN          BMW              P
# 378             31               SDN        NISSA              T
# 384             31               SDN         FORD              T
# 390             94               SDN         FORD              X
# 402             31               SDN        CHEVR              T
# 520             94               SDN        TOYOT              X
# 625             94              SUBN          KIA              X
# 746             31               SDN        NISSA              T
# 747             31               SDN        HONDA              T
#
#      Street Code1        ...         Violation Description  \
# 32          34510        ...                           NaN
# 51              0        ...                           NaN
# 57          24890        ...                           NaN
# 378         17790        ...                           NaN
# 384         34570        ...                           NaN
# 390             0        ...                           NaN
# 402         34570        ...                           NaN
# 520             0        ...                           NaN
# 625             0        ...                           NaN
# 746         34570        ...                           NaN
# 747         34570        ...                           NaN
#
#      No Standing or Stopping Violation  Hydrant Violation  \
# 32                                 NaN                NaN
# 51                                 NaN                NaN
# 57                                 NaN                NaN
# 378                                NaN                NaN
# 384                                NaN                NaN
# 390                                NaN                NaN
# 402                                NaN                NaN
# 520                                NaN                NaN
# 625                                NaN                NaN
# 746                                NaN                NaN
# 747                                NaN                NaN
#
#      Double Parking Violation  CODE  \
# 32                        NaN    31
# 51                        NaN    94
# 57                        NaN    31
# 378                       NaN    31
# 384                       NaN    31
# 390                       NaN    94
# 402                       NaN    31
# 520                       NaN    94
# 625                       NaN    94
# 746                       NaN    31
# 747                       NaN    31
#
#                                             DEFINITION  \
# 32   Standing of a non-commercial vehicle in a comm...
# 51   Vehicle Release Agreement code associated with...
# 57   Standing of a non-commercial vehicle in a comm...
# 378  Standing of a non-commercial vehicle in a comm...
# 384  Standing of a non-commercial vehicle in a comm...
# 390  Vehicle Release Agreement code associated with...
# 402  Standing of a non-commercial vehicle in a comm...
# 520  Vehicle Release Agreement code associated with...
# 625  Vehicle Release Agreement code associated with...
# 746  Standing of a non-commercial vehicle in a comm...
# 747  Standing of a non-commercial vehicle in a comm...
#
#                  Manhattan  96th St. & below  \
# 32                                     $115
# 51   100\n(Regular Tow, plus violation fine)
# 57                                     $115
# 378                                    $115
# 384                                    $115
# 390  100\n(Regular Tow, plus violation fine)
# 402                                    $115
# 520  100\n(Regular Tow, plus violation fine)
# 625  100\n(Regular Tow, plus violation fine)
# 746                                    $115
# 747                                    $115
#
#                            All Other Areas  _merge Parking Violation
# 32                                   $115     both             False
# 51   $200 (Heavy Tow, plus violation fine)    both             False
# 57                                   $115     both             False
# 378                                  $115     both             False
# 384                                  $115     both             False
# 390  $200 (Heavy Tow, plus violation fine)    both             False
# 402                                  $115     both             False
# 520  $200 (Heavy Tow, plus violation fine)    both             False
# 625  $200 (Heavy Tow, plus violation fine)    both             False
# 746                                  $115     both             False
# 747                                  $115     both             False
#
# [11 rows x 49 columns]

# %%
# df4.groupby('Parking Violation')[''].sum()[True]
df4['Street Name'].value_counts()
above_96_lst=[]
for x in df4['Street Name']: 
    if re.search(r'\S \d \S\w ', str(x)):
        above_96 =  False
        above_96_lst.append(above_96)
    elif re.search(r'\d[[Aa]-[Zz]][[Aa]-[Zz]] ', str(x)):
        above_96 =  False
        above_96_lst.append(above_96)
#         print(x, above_96)
    elif re.search(r'\w\s\d\d\s', str(x)):
        above_96 =  False
        above_96_lst.append(above_96)
#         print(x, above_96)
    elif re.search(r'[A-Z]\s\d\d[A-Z][A-Z] [A-Z][A-Z]', str(x)):
        above_96 =  False
        above_96_lst.append(above_96)
#         print(x, above_96)
    elif re.search(r'[0-2][A-Z][A-Z] AVE', str(x)):
        above_96 =  False
        above_96_lst.append(above_96)
#         print(x, above_96)
    else: 
        above_96 =  True
        above_96_lst.append(above_96)
#         print(x, above_96)

# above_96_lst.count(False)
df4['Above_96'] = above_96_lst
# Out:
# /Users/mercyemelike/.virtualenvs/data_analysis/lib/python3.5/site-packages/ipykernel/__main__.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df4 .h
# Out:
#      Summons Number  Plate ID Registration State Plate Type Issue Date  \
# 0        1283294138   GBB9093                 NY        PAS 2013-08-04
# 1        1283294151   62416MB                 NY        COM 2013-08-04
# 2        1283294163   78755JZ                 NY        COM 2013-08-05
# 3        1283294175   63009MA                 NY        COM 2013-08-05
# 5        1283294217    T60DAR                 NJ        PAS 2013-08-11
# 6        1283294229   GCR2838                 NY        PAS 2013-08-11
# 7        1283983620    XZ764G                 NJ        PAS 2013-08-07
# 8        1283983631   GBH9379                 NY        PAS 2013-08-07
# 9        1283983667    MCL78B                 NJ        PAS 2013-07-18
# 10       1283983679    M367CN                 NY        PAS 2013-07-18
# 11       1283983734   GAR6813                 NY        PAS 2013-07-18
# 12       1283983771   GEN8674                 NY        PAS 2013-07-31
# 13       1283983825   GAC2703                 NY        PAS 2013-08-12
# 14       1286036800   40793JY                 NY        COM 2013-07-05
# 15       1286123550   GAD1485                 NY        PAS 2013-08-12
# 16       1286246398   GFC5338                 NY        PAS 2013-07-26
# 17       1286246416   815M342                 MD        PAS 2013-07-30
# 18       1286248000   GJA3452                 NY        PAS 2013-07-23
# 19       1286282330   YZY6476                 NC        PAS 2013-07-29
# 20       1286282342    WBJ819                 LA        PAS 2013-08-07
# 21       1286289841   GAV9235                 NY        PAS 2013-07-20
# 22       1286654920    ZTR66R                 NJ        PAS 2013-07-18
# 23       1286799648   GDE3973                 NY        PAS 2013-07-20
# 24       1286807062   P193871                 IL        PAS 2013-08-10
# 25       1286807475   GGL6608                 NY        PAS 2013-07-26
# 26       1286807633   84301JU                 NY        COM 2013-07-19
# 27       1286808807   HHG3545                 PA        PAS 2013-08-06
# 28       1287320491   50097JX                 NY        COM 2013-08-07
# 29       1287320570   GEJ9154                 NY        PAS 2013-08-06
# 30       1287517304   6B22924                 ID        PAS 2013-07-22
# ..              ...       ...                ...        ...        ...
# 969      1334886817  T600324C                 NY        SRF 2013-07-12
# 970      1334893391   GEF8039                 NY        PAS 2013-08-08
# 971      1334899332   GAR5973                 NY        PAS 2013-05-28
# 972      1334899356     76860                 NY        MED 2013-07-11
# 973      1334900190    G44DBB                 NJ        PAS 2013-06-06
# 974      1334960409   GCP7978                 NY        PAS 2013-07-16
# 975      1334965547  T606011C                 NY        SRF 2013-08-18
# 976      1335085889   GEB4077                 NY        PAS 2013-08-05
# 977      1335086067    408861                 RI        PAS 2013-08-04
# 978      1335087308    505GSB                 OK        PAS 2013-08-21
# 979      1335087436   GGF7010                 NY        PAS 2013-08-14
# 980      1335087618    XH208F                 99        COM 2013-07-27
# 982      1335089433    49SD67                 NY        MOT 2013-08-05
# 983      1335089445   GDM5570                 NY        PAS 2013-08-20
# 984      1335089731    55RG48                 NY        MOT 2013-08-17
# 985      1335090538   GDF7589                 NY        PAS 2013-07-21
# 986      1335091440  PC613253                 99        PAS 2013-07-27
# 987      1335092730    82GN94                 NY        MOT 2013-08-17
# 988      1335092742    47RE79                 NY        MOT 2013-08-17
# 989      1335092754    78GX62                 NY        MOT 2013-08-17
# 990      1335092766    49SD33                 NY        MOT 2013-08-20
# 991      1335092778   GDU8731                 NY        PAS 2013-08-21
# 992      1335093072   GEN7535                 NY        PAS 2013-07-23
# 993      1335093199  T529952C                 NY        SRF 2013-08-01
# 994      1335093205   GBJ4073                 NY        PAS 2013-08-01
# 995      1335095342   JHA1050                 PA        PAS 2013-07-21
# 996      1335096139    72416R                 VA        PAS 2013-08-11
# 997      1335096140    HPJ538                 MS        PAS 2013-08-11
# 998      1335096152   HYW9707                 PA        PAS 2013-08-19
# 999      1335096395   HZC1957                 PA        PAS 2013-08-20
#
#     Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 0               46              SUBN         AUDI              P
# 1               46               VAN         FORD              P
# 2               46               P-U        CHEVR              P
# 3               46               VAN         FORD              P
# 5               14               P-U        DODGE              P
# 6               14               VAN          NaN              P
# 7               24              DELV         FORD              X
# 8               24               SDN        TOYOT              X
# 9               24               SDN        SUBAR              H
# 10              24               SDN        HYUND              H
# 11              24               SDN        TOYOT              H
# 12              24               SDN         AUDI              X
# 13              24               SDN        NISSA              X
# 14              14               VAN        CHEVR              P
# 15              20               SDN        VOLKS              T
# 16              14               SDN        TOYOT              T
# 17              20              SUBN        SATUR              T
# 18              14               SDN          KIA              T
# 19              20               SDN        NISSA              T
# 20              17              SUBN        HONDA              T
# 21              50               SDN        HONDA              T
# 22              50               SDN          N/S              T
# 23              40               SDN        TOYOT              T
# 24              40               SDN         SCIO              T
# 25              40               SDN        NISSA              T
# 26              14               P-U        DODGE              X
# 27              20               SDN        TOYOT              T
# 28              40               VAN        MERCU              T
# 29              51               VAN        TOYOT              X
# 30              20               SDN        VOLKS              T
# ..             ...               ...          ...            ...
# 969             17               VAN         FORD              X
# 970             14               SDN        HONDA              X
# 971             20              SUBN         FORD              H
# 972             20              SUBN        TOYOT              H
# 973             20               SDN         FORD              H
# 974             20               SDN        ME/BE              P
# 975             40               SDN        LINCO              P
# 976             24              SUBN          BMW              P
# 977             24               SDN        MAZDA              P
# 978             20               SDN        NISSA              P
# 979             24              SUBN         JEEP              P
# 980             20               VAN         FORD              P
# 982             51                MC        YAMAH              P
# 983             20              SUBN         FORD              P
# 984             51              MOTO        HONDA              P
# 985             24              SUBN          BMW              P
# 986             24              SUBN        CHEVR              P
# 987             51              MOTO        KAWAS              P
# 988             51              MOTO        KAWAS              P
# 989             51              MOTO        KAWAS              P
# 990             51              MOTO        KAWAS              P
# 991             24               SDN        INFIN              P
# 992             24               SDN        NISSA              P
# 993             50               SDN        LINCO              P
# 994             14              SUBN         FORD              P
# 995             40              SUBN          GMC              P
# 996             24              SUBN        ME/BE              P
# 997             24               SDN        HONDA              P
# 998             24              SUBN        VOLKS              P
# 999             24               VAN        HONDA              P
#
#      Street Code1   ...     No Standing or Stopping Violation  \
# 0           37250   ...                                   NaN
# 1           37290   ...                                   NaN
# 2           37030   ...                                   NaN
# 3           37270   ...                                   NaN
# 5           37250   ...                                   NaN
# 6           37250   ...                                   NaN
# 7           63430   ...                                   NaN
# 8           63430   ...                                   NaN
# 9               0   ...                                   NaN
# 10              0   ...                                   NaN
# 11              0   ...                                   NaN
# 12              0   ...                                   NaN
# 13          23230   ...                                   NaN
# 14          34190   ...                                   NaN
# 15          28930   ...                                   NaN
# 16              0   ...                                   NaN
# 17              0   ...                                   NaN
# 18          73690   ...                                   NaN
# 19          32030   ...                                   NaN
# 20              0   ...                                   NaN
# 21              0   ...                                   NaN
# 22              0   ...                                   NaN
# 23              0   ...                                   NaN
# 24          26630   ...                                   NaN
# 25          73650   ...                                   NaN
# 26          63030   ...                                   NaN
# 27          21130   ...                                   NaN
# 28          23190   ...                                   NaN
# 29          93230   ...                                   NaN
# 30          36250   ...                                   NaN
# ..            ...   ...                                   ...
# 969         37290   ...                                   NaN
# 970             0   ...                                   NaN
# 971         24240   ...                                   NaN
# 972         24240   ...                                   NaN
# 973         24240   ...                                   NaN
# 974         31820   ...                                   NaN
# 975         68720   ...                                   NaN
# 976         58730   ...                                   NaN
# 977         10810   ...                                   NaN
# 978         63030   ...                                   NaN
# 979         69230   ...                                   NaN
# 980         69230   ...                                   NaN
# 982         48830   ...                                   NaN
# 983         95030   ...                                   NaN
# 984         28430   ...                                   NaN
# 985             0   ...                                   NaN
# 986         39930   ...                                   NaN
# 987         34630   ...                                   NaN
# 988         34630   ...                                   NaN
# 989         34630   ...                                   NaN
# 990         23930   ...                                   NaN
# 991             0   ...                                   NaN
# 992         56230   ...                                   NaN
# 993             0   ...                                   NaN
# 994         56230   ...                                   NaN
# 995         19830   ...                                   NaN
# 996         34330   ...                                   NaN
# 997         34330   ...                                   NaN
# 998         34330   ...                                   NaN
# 999         68630   ...                                   NaN
#
#      Hydrant Violation  Double Parking Violation  CODE  \
# 0                  NaN                       NaN    46
# 1                  NaN                       NaN    46
# 2                  NaN                       NaN    46
# 3                  NaN                       NaN    46
# 5                  NaN                       NaN    14
# 6                  NaN                       NaN    14
# 7                  NaN                       NaN    24
# 8                  NaN                       NaN    24
# 9                  NaN                       NaN    24
# 10                 NaN                       NaN    24
# 11                 NaN                       NaN    24
# 12                 NaN                       NaN    24
# 13                 NaN                       NaN    24
# 14                 NaN                       NaN    14
# 15                 NaN                       NaN    20
# 16                 NaN                       NaN    14
# 17                 NaN                       NaN    20
# 18                 NaN                       NaN    14
# 19                 NaN                       NaN    20
# 20                 NaN                       NaN    17
# 21                 NaN                       NaN    50
# 22                 NaN                       NaN    50
# 23                 NaN                       NaN    40
# 24                 NaN                       NaN    40
# 25                 NaN                       NaN    40
# 26                 NaN                       NaN    14
# 27                 NaN                       NaN    20
# 28                 NaN                       NaN    40
# 29                 NaN                       NaN    51
# 30                 NaN                       NaN    20
# ..                 ...                       ...   ...
# 969                NaN                       NaN    17
# 970                NaN                       NaN    14
# 971                NaN                       NaN    20
# 972                NaN                       NaN    20
# 973                NaN                       NaN    20
# 974                NaN                       NaN    20
# 975                NaN                       NaN    40
# 976                NaN                       NaN    24
# 977                NaN                       NaN    24
# 978                NaN                       NaN    20
# 979                NaN                       NaN    24
# 980                NaN                       NaN    20
# 982                NaN                       NaN    51
# 983                NaN                       NaN    20
# 984                NaN                       NaN    51
# 985                NaN                       NaN    24
# 986                NaN                       NaN    24
# 987                NaN                       NaN    51
# 988                NaN                       NaN    51
# 989                NaN                       NaN    51
# 990                NaN                       NaN    51
# 991                NaN                       NaN    24
# 992                NaN                       NaN    24
# 993                NaN                       NaN    50
# 994                NaN                       NaN    14
# 995                NaN                       NaN    40
# 996                NaN                       NaN    24
# 997                NaN                       NaN    24
# 998                NaN                       NaN    24
# 999                NaN                       NaN    24
#
#                                             DEFINITION  \
# 0    Standing or parking on the roadway side of a v...
# 1    Standing or parking on the roadway side of a v...
# 2    Standing or parking on the roadway side of a v...
# 3    Standing or parking on the roadway side of a v...
# 5    General No Standing: Standing or parking where...
# 6    General No Standing: Standing or parking where...
# 7    Authorized Vehicles Only: No parking where par...
# 8    Authorized Vehicles Only: No parking where par...
# 9    Authorized Vehicles Only: No parking where par...
# 10   Authorized Vehicles Only: No parking where par...
# 11   Authorized Vehicles Only: No parking where par...
# 12   Authorized Vehicles Only: No parking where par...
# 13   Authorized Vehicles Only: No parking where par...
# 14   General No Standing: Standing or parking where...
# 15   General No Parking: No parking where parking i...
# 16   General No Standing: Standing or parking where...
# 17   General No Parking: No parking where parking i...
# 18   General No Standing: Standing or parking where...
# 19   General No Parking: No parking where parking i...
# 20   Authorized Vehicles Only: Standing or parking ...
# 21   Stopping, standing or parking in a crosswalk. ...
# 22   Stopping, standing or parking in a crosswalk. ...
# 23   Stopping, standing or parking closer than 15 f...
# 24   Stopping, standing or parking closer than 15 f...
# 25   Stopping, standing or parking closer than 15 f...
# 26   General No Standing: Standing or parking where...
# 27   General No Parking: No parking where parking i...
# 28   Stopping, standing or parking closer than 15 f...
# 29       Stopping, standing or parking on a sidewalk.
# 30   General No Parking: No parking where parking i...
# ..                                                 ...
# 969  Authorized Vehicles Only: Standing or parking ...
# 970  General No Standing: Standing or parking where...
# 971  General No Parking: No parking where parking i...
# 972  General No Parking: No parking where parking i...
# 973  General No Parking: No parking where parking i...
# 974  General No Parking: No parking where parking i...
# 975  Stopping, standing or parking closer than 15 f...
# 976  Authorized Vehicles Only: No parking where par...
# 977  Authorized Vehicles Only: No parking where par...
# 978  General No Parking: No parking where parking i...
# 979  Authorized Vehicles Only: No parking where par...
# 980  General No Parking: No parking where parking i...
# 982      Stopping, standing or parking on a sidewalk.
# 983  General No Parking: No parking where parking i...
# 984      Stopping, standing or parking on a sidewalk.
# 985  Authorized Vehicles Only: No parking where par...
# 986  Authorized Vehicles Only: No parking where par...
# 987      Stopping, standing or parking on a sidewalk.
# 988      Stopping, standing or parking on a sidewalk.
# 989      Stopping, standing or parking on a sidewalk.
# 990      Stopping, standing or parking on a sidewalk.
# 991  Authorized Vehicles Only: No parking where par...
# 992  Authorized Vehicles Only: No parking where par...
# 993  Stopping, standing or parking in a crosswalk. ...
# 994  General No Standing: Standing or parking where...
# 995  Stopping, standing or parking closer than 15 f...
# 996  Authorized Vehicles Only: No parking where par...
# 997  Authorized Vehicles Only: No parking where par...
# 998  Authorized Vehicles Only: No parking where par...
# 999  Authorized Vehicles Only: No parking where par...
#
#      Manhattan  96th St. & below  All Other Areas _merge  Parking Violation  \
# 0                          $115             $115    both               True
# 1                          $115             $115    both               True
# 2                          $115             $115    both               True
# 3                          $115             $115    both               True
# 5                          $115             $115    both               True
# 6                          $115             $115    both               True
# 7                           $65              $60    both               True
# 8                           $65              $60    both               True
# 9                           $65              $60    both               True
# 10                          $65              $60    both               True
# 11                          $65              $60    both               True
# 12                          $65              $60    both               True
# 13                          $65              $60    both               True
# 14                         $115             $115    both               True
# 15                          $65              $60    both               True
# 16                         $115             $115    both               True
# 17                          $65              $60    both               True
# 18                         $115             $115    both               True
# 19                          $65              $60    both               True
# 20                          $95              $95    both               True
# 21                         $115             $115    both               True
# 22                         $115             $115    both               True
# 23                         $115             $115    both               True
# 24                         $115             $115    both               True
# 25                         $115             $115    both               True
# 26                         $115             $115    both               True
# 27                          $65              $60    both               True
# 28                         $115             $115    both               True
# 29                         $115             $115    both               True
# 30                          $65              $60    both               True
# ..                           ...              ...    ...                ...
# 969                         $95              $95    both               True
# 970                        $115             $115    both               True
# 971                         $65              $60    both               True
# 972                         $65              $60    both               True
# 973                         $65              $60    both               True
# 974                         $65              $60    both               True
# 975                        $115             $115    both               True
# 976                         $65              $60    both               True
# 977                         $65              $60    both               True
# 978                         $65              $60    both               True
# 979                         $65              $60    both               True
# 980                         $65              $60    both               True
# 982                        $115             $115    both               True
# 983                         $65              $60    both               True
# 984                        $115             $115    both               True
# 985                         $65              $60    both               True
# 986                         $65              $60    both               True
# 987                        $115             $115    both               True
# 988                        $115             $115    both               True
# 989                        $115             $115    both               True
# 990                        $115             $115    both               True
# 991                         $65              $60    both               True
# 992                         $65              $60    both               True
# 993                        $115             $115    both               True
# 994                        $115             $115    both               True
# 995                        $115             $115    both               True
# 996                         $65              $60    both               True
# 997                         $65              $60    both               True
# 998                         $65              $60    both               True
# 999                         $65              $60    both               True
#
#     Above_96
# 0       True
# 1       True
# 2       True
# 3       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14     False
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
# 30      True
# ..       ...
# 969     True
# 970     True
# 971     True
# 972     True
# 973     True
# 974     True
# 975     True
# 976     True
# 977     True
# 978     True
# 979     True
# 980     True
# 982     True
# 983     True
# 984     True
# 985     True
# 986     True
# 987     True
# 988     True
# 989     True
# 990     True
# 991    False
# 992     True
# 993     True
# 994     True
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
#
# [990 rows x 50 columns]

# %% [markdown]
# ### 9. What's the most lucrative kind of parking violation? The most frequent?

# %% [markdown]
# ### 10. New Jersey has bad drivers, but does it have bad parkers, too? How much money does NYC make off of all non-New York vehicles?

# %% [markdown]
# ### 11. Make a chart of the top few.

# %% [markdown]
# ### 12. What time of day do people usually get their tickets? You can break the day up into several blocks - for example 12am-6am, 6am-12pm, 12pm-6pm, 6pm-12am.

# %% [markdown]
# ### 13. What's the average ticket cost in NYC?

# %% [markdown]
# ### 14. Make a graph of the number of tickets per day.

# %% [markdown]
# ### 15. Make a graph of the amount of revenue collected per day.

# %% [markdown]
# ### 16. Manually construct a dataframe out of https://dmv.ny.gov/statistic/2015licinforce-web.pdf (only NYC boroughts - bronx, queens, manhattan, staten island, brooklyn), having columns for borough name, abbreviation, and number of licensed drivers.

# %% [markdown]
# ### 17. What's the parking-ticket-$-per-licensed-driver in each borough of NYC? Do this with pandas and the dataframe you just made, not with your head!
